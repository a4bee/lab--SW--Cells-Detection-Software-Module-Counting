# %%
#pip install ultralytics

# %%
from ultralytics import YOLO
import os
import cv2
import matplotlib.pyplot as plt
import shutil

# %%
model = YOLO("algaex100-healthy-lowPH-infection-vol7_100epoch.pt")

# %%
dir_path = os.path.dirname(os.path.abspath("cells_count.ipynb"))
if(not os.path.exists(dir_path + "\cells_counted")): os.makedirs(dir_path + "\cells_counted")
if(os.path.exists(dir_path + "\\runs")): shutil.rmtree(dir_path + "\\runs", ignore_errors=True)

# %%
file_name = "test_photo4_100.jpg"
results = model.predict(file_name, save=True)
result = results[0]
# Out:
# image 1/1 c:\Users\aleksander.kolodziej\Desktop\lab--SW--Cells-Detection-Software-Module-Counting\test_photo4_100.jpg: 480x640 8 low_pHs, 1363.2ms
# Speed: 4.0ms preprocess, 1363.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs\detect\predict

# %%
count_algae = 0
count_infection = 0

for item in result.boxes:
    if(item.cls[0].item() == 0):
        count_algae +=1
    else: count_infection += 1

# %%
os.chdir(dir_path + "\\runs\detect\predict")
image = cv2.imread(file_name)

plt.imshow(image)
plt.show()

# %%
box = image[0:52, 0:265]
box_parameters = box.shape
for n in range(box_parameters[0]):
    for y in range(box_parameters[1]):
        box[n][y] = (0,0,0)

image = cv2.putText(image, "Counted Low pH:   " + str(count_infection), (5,45), cv2.FONT_HERSHEY_SIMPLEX , 0.75, (255, 255, 255), 2, cv2.LINE_AA)
if(count_algae < 10):
    image = cv2.putText(image, "Counted Healthy:   " + str(count_algae), (5,20), cv2.FONT_HERSHEY_SIMPLEX , 0.75, (255, 255, 255), 2, cv2.LINE_AA)
else: image = cv2.putText(image, "Counted Healthy:  " + str(count_algae), (5,20), cv2.FONT_HERSHEY_SIMPLEX , 0.75, (255, 255, 255), 2, cv2.LINE_AA)

# %%
os.chdir(dir_path + "\cells_counted")
cv2.imwrite(file_name, image)
# Out:
# True
